# %% [markdown]
# ## Pycharm Template Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Query Redshift and Save to S3

# %%
UNLOAD ('SELECT *
FROM analytics_scratch.table_name')
TO 's3://turo-xyz-sagemaker/folder_name/table_name.csv'
ACCESS_KEY_ID ''
SECRET_ACCESS_KEY ''
SESSION_TOKEN ''
PARALLEL OFF
ALLOWOVERWRITE
HEADER
CSV
;

# %% [markdown]
# ### Load in Data Saved in S3
# ##### Saml2aws login in terminal

# %%
import awswrangler as wr

# %%
df = wr.s3.read_csv('s3_uri')

# %% [markdown]
# ### Pull in data manually from a local csv

# %%
##Pull in data manually from a local csv
#df1 = pd.read_csv("raw_data_to_compare/ap_dataset_id_119_2025_04_11T17_12_50.csv")
